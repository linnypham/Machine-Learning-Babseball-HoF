# %% [markdown]
# # Machine Learning Project
# ## Predicting Hall-of-Fame players

# %% [markdown]
# Extract HoF players' id and change to player id

# %%
import pandas as pd

df = pd.read_csv('data/HallOfFame.csv')
hof_id = df[df['category'] == 'Player']['hofID']
player_id = hof_id.str[:-1]
print(player_id.to_string())
# Out:
# 0        cobbty01
# 1        ruthba01
# 2       wagneho01
# 3       mathech01
# 4       johnswa01
# 5       lajoina01
# 6       speaktr01
# 7       youngcy01
# 8       hornsro01
# 9       cochrmi01
# 10      sislege01
# 11      collied01
# 12      colliji01
# 13      alexape01
# 14      gehrilo01
# 15      bresnro01
# 16      keelewi01
# 17      ansonca01
# 18      ewingbu01
# 19      keelewi01
# 20      wadderu01
# 21      youngcy01
# 22      delahed01
# 23       foxxji01
# 24      walshed01
# 25      mcgrajo01
# 26      delahed01
# 27      radboch01
# 28      traynpi01
# 29      kellyki01
# 30       longhe01
# 31      friscfr01
# 32      grovele01
# 33      jennihu01
# 34      rusieam01
# 35      chaseha01
# 36      youngro01
# 37      clarkfr01
# 38      terrybi01
# 39      colliji01
# 40      klingjo01
# 41      crigelo01
# 42      comisch01
# 43      dennyje01
# 44      langebi01
# 45      robinwi01
# 46      stoveha01
# 47      wrighge01
# 48      brownmo01
# 49      eversjo01
# ...
